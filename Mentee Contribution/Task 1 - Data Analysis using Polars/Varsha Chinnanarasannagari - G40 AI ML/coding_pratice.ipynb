# %%
balance=5000
min_bal=1000
withdrawal=float(input("enter the withdrawal amount:"))
if withdrawal<(balance-min_bal):
  balance=balance-withdrawal
  print("balance amount:",balance)
else:
  print("insufficient balance")
# Out:
# enter the withdrawal amount:3000
# balance amount: 2000.0

# %%
age=int(input("enter the age:"))
if age<=5:
  print("ticket is free")
elif age<=18:
  print("ticket price 100")
elif age<=40:
  print("ticket price is 200")
elif age<60:
  print("ticket price 150")

# %%
side1=int(input("enter the side1:"))
side2=int(input("enter the side2:"))
side3=int(input("enter the side3:"))
if side1+side2+side3==180:
  print("three angles can form triangle")
else:
  print("cannot form triangle")

# %%
correct_admin="varsha"
correct_password="varsha234"
attempts=3
while attempts>0:
  admin=input("enter the admin name:")
  password=input("enter the password:")
  if admin==correct_admin and password==correct_password:
    print("login success")
    break
  else:
      attempts-=1
      print("invaild password and admin")
      print("remaining attempts:",attempts)
if attempts==0:
  print("account locked")
# Out:
# enter the admin name:varsha
# enter the password:vashk90
# invaild password and admin
# remaining attempts: 2
# enter the admin name:varsha
# enter the password:varsha234
# login success

# %%
side1=int(input("enter the side1:"))
side2=int(input("enter the side2:"))
side3=int(input("enter the side3:"))
if side1==side2==side3:
  print("equilateral triangle")
elif side1==side2 or side2==side3 or side1==side3:
  print("isosceles triangle")
else:
  print("scalene triangle")
# Out:
# enter the side1:45
# enter the side2:45
# enter the side3:5
# isosceles triangle

# %%
num=int(input("enter the number:"))
if num>0:
  print(num,"is positive")
elif num<0:
  print(num,"is neagtive")
else:
  print(num,"zero")
if num%2==0:
  print(num,"is even")
else:
  print(num,"is odd")
# Out:
# enter the number:56
# 56 is positive
# 56 is even

# %%
amount=float(input("enter the amount:"))
membership=input("do you any membership(yes or no):")
if amount>5000 and membership=="yes":
  print("discount is 20%")
elif amount>2000 and membership=="yes":
  print("discount is 10%")
elif amount>5000 and membership=="no":
  print("discount is 5%")
elif amount>2000 and membership=="no":
  print("no discount")
# Out:
# enter the amount:4000
# do you any membership(yes or no):yes
# discount is 10%

# %%
years=int(input("enter the experince:"))
rating=input("enter the rating(1,2,3,4,5):")
if years>5 and rating>=3:
  print("employee has promotion eligibility")
else:
  print("employee doesn't have eligibility")
# Out:
# enter the experince:5
# enter the rating(1,2,3,4,5):2
# employee doesn't have eligibility

# %%
marks=int(input("enter the marks"))
income=float(input("enter the income:"))
if marks >=85 and income<=30000:
  print("eligible to scholarship")
else:
  print("not eligible")
# Out:
# enter the marks89
# enter the income:15000
# eligible to get scholarship

# %%
correct_password="varsha789"
correct_otp="1244"
attempts=3
while attempts>0:
  password=input("enter the password:")
  if password==correct_password:
    otp=input("enter the otp")
    if otp==correct_otp:
      print("login success")
      break
    else:
      print("invaild otp")
  else:
    print("invaild password")
  attempts-=1
  print("attempts left:",attempts)
if attempts==0:
  print("account locked")
# Out:
# enter the password:varsha789
# enter the otp245
# invaild otp
# attempts left: 2
# enter the password:varsha789
# enter the otp1244
# login success
